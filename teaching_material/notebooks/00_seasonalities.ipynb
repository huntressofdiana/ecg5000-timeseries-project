# %% [markdown]
# # Seasonalities
#
# Aspects of seasonalities

# %% [markdown]
# ## Energy Consumption (Germany)
#
# public Open Power System Data hourly dataset. The German variable is total electricity load in MW, sourced from ENTSO-E. The dataset covers 2015 to September 2020.

# %%
import pandas as pd
import matplotlib.pyplot as plt
url = ("https://physionet.org/files/bidmc/1.0.0/bidmc_csv/bidmc_01_Numerics.csv")
df = pd.read_csv(url)

time = df.index / 60  # observations are one second apart
df.columns = df.columns.str.strip() # strip whitespace from column names
print(repr(df.columns.tolist()))
# Out:
# ['Time [s]', 'HR', 'PULSE', 'RESP', 'SpO2']

# %% [markdown]
# ### univariate sequence
#
# let's pick the heart rate. single channel measured over time

# %%
plt.figure(figsize=(10, 3))
plt.plot(time, df["HR"], color="black")
plt.xlabel("Time (minutes)")
plt.ylabel("Heart rate (bpm)")
plt.show()

# %% [markdown]
# ### multivariate sequence
#
# multiple channels / sensors recorded synchronously over time

# %%
fig, axes = plt.subplots(3, 1, figsize=(10, 5), sharex=True)

for ax, variable, label in zip(
    axes,
    ["HR", "RESP", "SpO2"],
    ["HR (bpm)", "RESP (breaths/min)", "SpO2 (%)"]
):
    ax.plot(time, df[variable], color="black")
    ax.set_ylabel(label)

axes[-1].set_xlabel("Time (minutes)")
plt.tight_layout()
plt.show()
